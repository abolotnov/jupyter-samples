# %% [markdown]
# # Jupyter-based interactive computing
#
#  - Load data from feed
#  - Clean the data
#  - Validate the data
#  - Map the data into a new data structure
#  - Perform calculations
#  - Build a simple report

# %% [markdown]
# ## Use Cases in mind
#
# ![Use Cases](UseCases.png "Use Cases")

# %% [markdown]
# ## Components Structure
#
# ![Components](Components.png "Components Layout")

# %% [markdown]
# ## In this demonstration
#
#  - Read a datafeed into a dataframe
#  - Perform Basic data cleaning routines
#  - Export clean data to HTML and CSV
#  - Diff between datasets
#  - Construction of custom datasets programatically
#  - Constrcuction of custom datasets with UI widgets
#  - Saving of custom datasets into CSV

# %% [markdown]
# ## Setup environment
#
# The vision is to build templates covering key data manipulation routines - this way users only need to open a template to get going - they will be able to modify it as they go and save the changes

# %%
import pandas as pd, numpy as np, ipywidgets as widgets, sys
pd.options.display.max_columns = 50
feed_file = 'LoanStats3a.csv'

# %% [markdown]
# ## Importing data from a feed
#
# We are using `pandas` framework (popular for data science) for data manipulations. It's fairly easy to learn and very performant.

# %%
data = pd.read_csv(feed_file, low_memory=False)
data.head(2)
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN       5000         5000           4975.0   36 months
# 1 NaN        NaN       2500         2500           2500.0   60 months
#
#   int_rate  installment grade sub_grade emp_title emp_length home_ownership  \
# 0   10.65%       162.87     B        B2       NaN  10+ years           RENT
# 1   15.27%        59.83     C        C4     Ryder   < 1 year           RENT
#
#    annual_inc verification_status   issue_d  loan_status pymnt_plan  url  \
# 0     24000.0            Verified  Dec-2011   Fully Paid          n  NaN
# 1     30000.0     Source Verified  Dec-2011  Charged Off          n  NaN
#
#                                                 desc      purpose     title  \
# 0    Borrower added on 12/22/11 > I need to upgra...  credit_card  Computer
# 1    Borrower added on 12/22/11 > I plan to use t...          car      bike
#
#   zip_code addr_state    dti       ...         \
# 0    860xx         AZ  27.65       ...
# 1    309xx         GA   1.00       ...
#
#    sec_app_collections_12_mths_ex_med sec_app_mths_since_last_major_derog  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
#
#    hardship_flag  hardship_type  hardship_reason  hardship_status  \
# 0              N            NaN              NaN              NaN
# 1              N            NaN              NaN              NaN
#
#    deferral_term  hardship_amount hardship_start_date  hardship_end_date  \
# 0            NaN              NaN                 NaN                NaN
# 1            NaN              NaN                 NaN                NaN
#
#   payment_plan_start_date  hardship_length  hardship_dpd  \
# 0                     NaN              NaN           NaN
# 1                     NaN              NaN           NaN
#
#    hardship_loan_status  orig_projected_additional_accrued_interest  \
# 0                   NaN                                         NaN
# 1                   NaN                                         NaN
#
#    hardship_payoff_balance_amount  hardship_last_payment_amount  \
# 0                             NaN                           NaN
# 1                             NaN                           NaN
#
#    disbursement_method  debt_settlement_flag  debt_settlement_flag_date  \
# 0                 Cash                     N                        NaN
# 1                 Cash                     N                        NaN
#
#   settlement_status  settlement_date  settlement_amount settlement_percentage  \
# 0               NaN              NaN                NaN                   NaN
# 1               NaN              NaN                NaN                   NaN
#
#    settlement_term
# 0              NaN
# 1              NaN
#
# [2 rows x 145 columns]

# %% [markdown]
# ## Data Cleaning
#
#  - Let's remove empty columns
#  - Let's remove leaning and trailing spaces ' 36 month ' will become '36 months'

# %%
data = data.dropna(1, how='all')
data.head(2)
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0       5000         5000           4975.0   36 months   10.65%       162.87
# 1       2500         2500           2500.0   60 months   15.27%        59.83
#
#   grade sub_grade emp_title emp_length home_ownership  annual_inc  \
# 0     B        B2       NaN  10+ years           RENT     24000.0
# 1     C        C4     Ryder   < 1 year           RENT     30000.0
#
#   verification_status   issue_d  loan_status pymnt_plan  \
# 0            Verified  Dec-2011   Fully Paid          n
# 1     Source Verified  Dec-2011  Charged Off          n
#
#                                                 desc      purpose     title  \
# 0    Borrower added on 12/22/11 > I need to upgra...  credit_card  Computer
# 1    Borrower added on 12/22/11 > I plan to use t...          car      bike
#
#   zip_code addr_state    dti  delinq_2yrs earliest_cr_line  inq_last_6mths  \
# 0    860xx         AZ  27.65            0         Jan-1985               1
# 1    309xx         GA   1.00            0         Apr-1999               5
#
#         ...         total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 0       ...                 5000.00         863.16                 0.0
# 1       ...                  456.46         435.17                 0.0
#
#    recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt  \
# 0         0.0                     0.00     Jan-2015           171.62
# 1       122.9                     1.11     Apr-2013           119.66
#
#   last_credit_pull_d  collections_12_mths_ex_med  policy_code  \
# 0           Feb-2018                           0            1
# 1           Oct-2016                           0            1
#
#    application_type  acc_now_delinq  chargeoff_within_12_mths  delinq_amnt  \
# 0        Individual               0                         0            0
# 1        Individual               0                         0            0
#
#    pub_rec_bankruptcies  tax_liens  hardship_flag disbursement_method  \
# 0                     0          0              N                Cash
# 1                     0          0              N                Cash
#
#    debt_settlement_flag debt_settlement_flag_date  settlement_status  \
# 0                     N                       NaN                NaN
# 1                     N                       NaN                NaN
#
#    settlement_date settlement_amount  settlement_percentage  settlement_term
# 0              NaN               NaN                    NaN              NaN
# 1              NaN               NaN                    NaN              NaN
#
# [2 rows x 62 columns]

# %% [markdown]
# Stripping spaces is a simple function:

# %%
def StripSpaces(df):
    cols = df.select_dtypes([np.object_]).columns
    for c in cols:
        df[c] = df[c].str.strip()
    return df

data = StripSpaces(data)
data.head(2)
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv       term int_rate  installment  \
# 0       5000         5000           4975.0  36 months   10.65%       162.87
# 1       2500         2500           2500.0  60 months   15.27%        59.83
#
#   grade sub_grade emp_title emp_length home_ownership  annual_inc  \
# 0     B        B2       NaN  10+ years           RENT     24000.0
# 1     C        C4     Ryder   < 1 year           RENT     30000.0
#
#   verification_status   issue_d  loan_status pymnt_plan  \
# 0            Verified  Dec-2011   Fully Paid          n
# 1     Source Verified  Dec-2011  Charged Off          n
#
#                                                 desc      purpose     title  \
# 0  Borrower added on 12/22/11 > I need to upgrade...  credit_card  Computer
# 1  Borrower added on 12/22/11 > I plan to use thi...          car      bike
#
#   zip_code addr_state    dti  delinq_2yrs earliest_cr_line  inq_last_6mths  \
# 0    860xx         AZ  27.65            0         Jan-1985               1
# 1    309xx         GA   1.00            0         Apr-1999               5
#
#         ...         total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 0       ...                 5000.00         863.16                 0.0
# 1       ...                  456.46         435.17                 0.0
#
#    recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt  \
# 0         0.0                     0.00     Jan-2015           171.62
# 1       122.9                     1.11     Apr-2013           119.66
#
#   last_credit_pull_d  collections_12_mths_ex_med  policy_code  \
# 0           Feb-2018                           0            1
# 1           Oct-2016                           0            1
#
#    application_type  acc_now_delinq  chargeoff_within_12_mths  delinq_amnt  \
# 0        Individual               0                         0            0
# 1        Individual               0                         0            0
#
#    pub_rec_bankruptcies  tax_liens  hardship_flag disbursement_method  \
# 0                     0          0              N                Cash
# 1                     0          0              N                Cash
#
#    debt_settlement_flag debt_settlement_flag_date  settlement_status  \
# 0                     N                       NaN                NaN
# 1                     N                       NaN                NaN
#
#    settlement_date settlement_amount  settlement_percentage  settlement_term
# 0              NaN               NaN                    NaN              NaN
# 1              NaN               NaN                    NaN              NaN
#
# [2 rows x 62 columns]

# %% [markdown]
# ## Saving clean data to files
#
#  - CSV
#  - HTML
#  - There are many other formats available, including SQL, local database files and specific framework formats, too

# %%
name = "LoanStat3a-Cleaned"
with open(name+'.html', 'w') as f:
    f.write(data.head(100).to_html())

data.head(100).to_csv(name+'.csv')

# %% [markdown]
# ## Constructing custom sets
#
#  - Let's pick three columns from original feed and make a custom dataframe out of it
#  - Let's inspect the frame

# %%
data_small = data[['issue_d','term','int_rate','funded_amnt']].head(10)
data_small['term'] = data_small['term'].str.strip()
data_small.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
# issue_d        10 non-null object
# term           10 non-null object
# int_rate       10 non-null object
# funded_amnt    10 non-null int64
# dtypes: int64(1), object(3)
# memory usage: 400.0+ bytes

# %% [markdown]
# ## Data diffs
#
# In this sample, we will use the newly created custom set and modify one to be different and build a small widget that will display columns side by side and highlight differences.

# %%
data_small1 = data_small.copy()
data_small1['funded_amnt'] = data_small1['funded_amnt'] * 1.2
data_small1.loc[data_small1['term'] == '36 months', 'int_rate'] = '10.10%'

# %%
data_both=pd.concat([data_small, data_small1], axis='columns', keys=['Original', 'Updated'])
data_swapped=data_both.swaplevel(axis='columns')[data_small.columns[1:]]
def highlight_diff(data, color='yellow'):
    attr = 'background-color: {}'.format(color)
    other = data.xs('Original', axis='columns', level=-1)
    return pd.DataFrame(np.where(data.ne(other, level=0), attr, ''),
                        index=data.index, columns=data.columns)

data_swapped.style.apply(highlight_diff, axis=None)
# Out:
# <style  type="text/css" >
#     #T_82640f66_8070_11e8_8a50_72000620db90row0_col3 {
#             background-color:  yellow;
#         }    #T_82640f66_8070_11e8_8a50_72000620db90row0_col5 {
#             background-color:  yellow;
#         }    #T_82640f66_8070_11e8_8a50_72000620db90row1_col5 {
#             background-color:  yellow;
#         }    #T_82640f66_8070_11e8_8a50_72000620db90row2_col3 {
#             background-color:  yellow;
#         }    #T_82640f66_8070_11e8_8a50_72000620db90row2_col5 {
#             background-color:  yellow;
#         }    #T_82640f66_8070_11e8_8a50_72000620db90row3_col3 {
#             background-color:  yellow;
#         }    #T_82640f66_8070_11e8_8a50_72000620db90row3_col5 {
#             background-color:  yellow;
#         }    #T_82640f66_8070_11e8_8a50_72000620db90row4_col5 {
#             background-color:  yellow;
#         }    #T_82640f66_8070_11e8_8a50_72000620db90row5_col3 {
#             background-color:  yellow;
#         }    #T_82640f66_8070_11e8_8a50_72000620db90row5_col5 {
#             background-color:  yellow;
#         }    #T_82640f66_8070_11e8_8a50_72000620db90row6_col5 {
#             background-color:  yellow;
#         }    #T_82640f66_8070_11e8_8a50_72000620db90row7_col3 {
#             background-color:  yellow;
#         }    #T_82640f66_8070_11e8_8a50_72000620db90row7_col5 {
#             background-color:  yellow;
#         }    #T_82640f66_8070_11e8_8a50_72000620db90row8_col5 {
#             background-color:  yellow;
#         }    #T_82640f66_8070_11e8_8a50_72000620db90row9_col5 {
#             background-color:  yellow;
#         }</style>
# <table id="T_82640f66_8070_11e8_8a50_72000620db90" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" colspan=2>term</th>
#         <th class="col_heading level0 col2" colspan=2>int_rate</th>
#         <th class="col_heading level0 col4" colspan=2>funded_amnt</th>
#     </tr>    <tr>
#         <th class="blank level1" ></th>
#         <th class="col_heading level1 col0" >Original</th>
#         <th class="col_heading level1 col1" >Updated</th>
#         <th class="col_heading level1 col2" >Original</th>
#         <th class="col_heading level1 col3" >Updated</th>
#         <th class="col_heading level1 col4" >Original</th>
#         <th class="col_heading level1 col5" >Updated</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_82640f66_8070_11e8_8a50_72000620db90level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_82640f66_8070_11e8_8a50_72000620db90row0_col0" class="data row0 col0" >36 months</td>
#         <td id="T_82640f66_8070_11e8_8a50_72000620db90row0_col1" class="data row0 col1" >36 months</td>
#         <td id="T_82640f66_8070_11e8_8a50_72000620db90row0_col2" class="data row0 col2" >10.65%</td>
#         <td id="T_82640f66_8070_11e8_8a50_72000620db90row0_col3" class="data row0 col3" >10.10%</td>
#         <td id="T_82640f66_8070_11e8_8a50_72000620db90row0_col4" class="data row0 col4" >5000</td>
#         <td id="T_82640f66_8070_11e8_8a50_72000620db90row0_col5" class="data row0 col5" >6000</td>
#     </tr>    <tr>
#         <th id="T_82640f66_8070_11e8_8a50_72000620db90level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_82640f66_8070_11e8_8a50_72000620db90row1_col0" class="data row1 col0" >60 months</td>
#         <td id="T_82640f66_8070_11e8_8a50_72000620db90row1_col1" class="data row1 col1" >60 months</td>
#         <td id="T_82640f66_8070_11e8_8a50_72000620db90row1_col2" class="data row1 col2" >15.27%</td>
#         <td id="T_82640f66_8070_11e8_8a50_72000620db90row1_col3" class="data row1 col3" >15.27%</td>
#         <td id="T_82640f66_8070_11e8_8a50_72000620db90row1_col4" class="data row1 col4" >2500</td>
#         <td id="T_82640f66_8070_11e8_8a50_72000620db90row1_col5" class="data row1 col5" >3000</td>
#     </tr>    <tr>
#         <th id="T_82640f66_8070_11e8_8a50_72000620db90level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_82640f66_8070_11e8_8a50_72000620db90row2_col0" class="data row2 col0" >36 months</td>
#         <td id="T_82640f66_8070_11e8_8a50_72000620db90row2_col1" class="data row2 col1" >36 months</td>
#         <td id="T_82640f66_8070_11e8_8a50_72000620db90row2_col2" class="data row2 col2" >15.96%</td>
#         <td id="T_82640f66_8070_11e8_8a50_72000620db90row2_col3" class="data row2 col3" >10.10%</td>
#         <td id="T_82640f66_8070_11e8_8a50_72000620db90row2_col4" class="data row2 col4" >2400</td>
#         <td id="T_82640f66_8070_11e8_8a50_72000620db90row2_col5" class="data row2 col5" >2880</td>
#     </tr>    <tr>
#         <th id="T_82640f66_8070_11e8_8a50_72000620db90level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_82640f66_8070_11e8_8a50_72000620db90row3_col0" class="data row3 col0" >36 months</td>
#         <td id="T_82640f66_8070_11e8_8a50_72000620db90row3_col1" class="data row3 col1" >36 months</td>
#         <td id="T_82640f66_8070_11e8_8a50_72000620db90row3_col2" class="data row3 col2" >13.49%</td>
#         <td id="T_82640f66_8070_11e8_8a50_72000620db90row3_col3" class="data row3 col3" >10.10%</td>
#         <td id="T_82640f66_8070_11e8_8a50_72000620db90row3_col4" class="data row3 col4" >10000</td>
#         <td id="T_82640f66_8070_11e8_8a50_72000620db90row3_col5" class="data row3 col5" >12000</td>
#     </tr>    <tr>
#         <th id="T_82640f66_8070_11e8_8a50_72000620db90level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_82640f66_8070_11e8_8a50_72000620db90row4_col0" class="data row4 col0" >60 months</td>
#         <td id="T_82640f66_8070_11e8_8a50_72000620db90row4_col1" class="data row4 col1" >60 months</td>
#         <td id="T_82640f66_8070_11e8_8a50_72000620db90row4_col2" class="data row4 col2" >12.69%</td>
#         <td id="T_82640f66_8070_11e8_8a50_72000620db90row4_col3" class="data row4 col3" >12.69%</td>
#         <td id="T_82640f66_8070_11e8_8a50_72000620db90row4_col4" class="data row4 col4" >3000</td>
#         <td id="T_82640f66_8070_11e8_8a50_72000620db90row4_col5" class="data row4 col5" >3600</td>
#     </tr>    <tr>
#         <th id="T_82640f66_8070_11e8_8a50_72000620db90level0_row5" class="row_heading level0 row5" >5</th>
#         <td id="T_82640f66_8070_11e8_8a50_72000620db90row5_col0" class="data row5 col0" >36 months</td>
#         <td id="T_82640f66_8070_11e8_8a50_72000620db90row5_col1" class="data row5 col1" >36 months</td>
#         <td id="T_82640f66_8070_11e8_8a50_72000620db90row5_col2" class="data row5 col2" >7.90%</td>
#         <td id="T_82640f66_8070_11e8_8a50_72000620db90row5_col3" class="data row5 col3" >10.10%</td>
#         <td id="T_82640f66_8070_11e8_8a50_72000620db90row5_col4" class="data row5 col4" >5000</td>
#         <td id="T_82640f66_8070_11e8_8a50_72000620db90row5_col5" class="data row5 col5" >6000</td>
#     </tr>    <tr>
#         <th id="T_82640f66_8070_11e8_8a50_72000620db90level0_row6" class="row_heading level0 row6" >6</th>
#         <td id="T_82640f66_8070_11e8_8a50_72000620db90row6_col0" class="data row6 col0" >60 months</td>
#         <td id="T_82640f66_8070_11e8_8a50_72000620db90row6_col1" class="data row6 col1" >60 months</td>
#         <td id="T_82640f66_8070_11e8_8a50_72000620db90row6_col2" class="data row6 col2" >15.96%</td>
#         <td id="T_82640f66_8070_11e8_8a50_72000620db90row6_col3" class="data row6 col3" >15.96%</td>
#         <td id="T_82640f66_8070_11e8_8a50_72000620db90row6_col4" class="data row6 col4" >7000</td>
#         <td id="T_82640f66_8070_11e8_8a50_72000620db90row6_col5" class="data row6 col5" >8400</td>
#     </tr>    <tr>
#         <th id="T_82640f66_8070_11e8_8a50_72000620db90level0_row7" class="row_heading level0 row7" >7</th>
#         <td id="T_82640f66_8070_11e8_8a50_72000620db90row7_col0" class="data row7 col0" >36 months</td>
#         <td id="T_82640f66_8070_11e8_8a50_72000620db90row7_col1" class="data row7 col1" >36 months</td>
#         <td id="T_82640f66_8070_11e8_8a50_72000620db90row7_col2" class="data row7 col2" >18.64%</td>
#         <td id="T_82640f66_8070_11e8_8a

# %% [markdown]
# ## Data building with widgets
#
# In this example, we are buidling a simple widget that will let us do the following:
#
#  - Select a data feed to read
#  - Select columns we want to retain in new feed
#  - Override the names for the selected columns
#  - Select data types for the columns
#  - Save the new set into CSV

# %%
def dTypeToType(t):
    """Takes pandas dtype (dataframe['column_name'].dtype.kind) as input and returns its python type representation"""
    return{
        'b':'boolean',
        'i':'(signed) integer',
        'u':'unsigned integer',
        'f':'floating-point',
        'c':'complex-floating point',
        'O':'(Python) objects',
        'S':'(byte-)string',
        'a':'(byte-)string',
        'U':'Unicode',
        'V':'raw data (void)',
    }[t]  

def dTypesAll():
    return ['float','int','bool','datetime64[ns]','datetime64[ns, tz]','timedelta[ns]','category','object']

# %%
def render_mapper():
    import os
    from IPython.lib.pretty import pretty

    # Layouts for formatting
    layout180 = widgets.Layout(width='180px', height='25px')
    layout260 = widgets.Layout(width='260px', height='25px')
    layout999 = widgets.Layout(width='999px', height='260px', display='block', overflow_y='auto')
    layout1 = widgets.Layout(flex='0 0 28px', min_height='28px', overflow_y='hidden')

    debug_view = widgets.Output(layout={'border': '1px solid black'})
    # Dropdown for input file
    files = [x for x in os.listdir() if '.csv' in x]

    files_dd = widgets.Dropdown(
        options=files,
        description='Select Feed File:',
        disabled=False,
    )

    upload_button = widgets.Button(description="Read file...")

    # Let's build the header rows
    header_row = widgets.HBox(children=[widgets.Label("Use in new set?", layout=layout260),
                                        widgets.Label("Rename in new set", layout=layout180),
                                        widgets.Label("Current Type", layout=layout260),
                                        widgets.Label("Convert to Type", layout=layout260)])

    text = widgets.Text(description='Set Name:')
    # Let's add a button and a onclick handler for it
    btn = widgets.Button(description="Generate Set")

    # Let's build the msg area for debug purposes
    msg = widgets.Textarea(layout=widgets.Layout(width='1020px', height='200px'))

    # Building the actual rows based on small_data set defined in cells above
    @debug_view.capture(clear_output=True)
    def get_columns(data_set):
        rows = []
        for x in data_set.columns:
            rows.append(widgets.HBox(children=[widgets.Checkbox(description=x, layout=layout260),
                                               widgets.Text(value=x, layout=layout180),
                                               widgets.Label(value=dTypeToType(data_set[x].dtype.kind),
                                                             layout=layout260),
                                               widgets.Dropdown(options=dTypesAll(), layout=layout260)
                                               ], layout=layout1))
        ui.children = rows

    @debug_view.capture(clear_output=True)
    def read_file(b):
        global input_set
        global data
        input_set = pd.read_csv(files_dd.value)
        msg.value = pretty(input_set.columns)
        get_columns(input_set)
        # msg.value = pretty(ui.children)

    @debug_view.capture(clear_output=True)
    def generate_set(b):
        old_columns = []
        new_columns = []
        for x in ui.children:
            if x.children[0].value:
                old_columns.append(x.children[0].description)
                new_columns.append(x.children[1].value)
        new_set = input_set[old_columns]
        new_set.columns = new_columns
        msg.value = pretty(str(new_set.columns) + str(new_set.size))
        new_set.to_csv(text.value+'.csv', index=False)

    upload_button.on_click(read_file)
    btn.on_click(generate_set)

    top_row = widgets.VBox(children=[widgets.HBox(children=[files_dd, upload_button])])
    ui = widgets.VBox()
    
    control = widgets.VBox(children=[top_row])
    data = widgets.VBox(children=[header_row, ui], layout=layout999)
    footer_row = widgets.VBox(children=[widgets.HBox(children=[text, btn]), msg, debug_view])

    display(control)
    display(data)
    display(footer_row)

# %%
render_mapper()
# Out:
# VBox(children=(VBox(children=(HBox(children=(Dropdown(description='Select Feed File:', options=('LoanStats3a.c…
# VBox(children=(HBox(children=(Label(value='Use in new set?', layout=Layout(height='25px', width='260px')), Lab…
# VBox(children=(HBox(children=(Text(value='', description='Set Name:'), Button(description='Generate Set', styl…
